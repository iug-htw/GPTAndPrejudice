# %%
from circuit_tasks import build_gender_swap_pairs

pairs = build_gender_swap_pairs(n=64)  # (clean, corrupt, target, distractor)

# %%
pairs
# Out:
# [('Anne arrived at Netherfield after a long journey. Without hesitation, ',
#   'William arrived at Netherfield after a long journey. Without hesitation, ',
#   'she',
#   'he'),
#  ('Marianne arrived at Pemberley after a long journey. Without hesitation, ',
#   'Henry arrived at Pemberley after a long journey. Without hesitation, ',
#   'she',
#   'he'),
#  ('Marianne arrived at Bath after a long journey. Without hesitation, ',
#   'Henry arrived at Bath after a long journey. Without hesitation, ',
#   'she',
#   'he'),
#  ('Catherine arrived at Bath after a long journey. Without hesitation, ',
#   'Knightley arrived at Bath after a long journey. Without hesitation, ',
#   'she',
#   'he'),
#  ('Emma arrived at Hertfordshire after a long journey. Without hesitation, ',
#   'Bingley arrived at Hertfordshire after a long journey. Without hesitation, ',
#   'she',
#   'he'),
#  ('Marianne arrived at Bath after a long journey. Without hesitation, ',
# ...
