# %%
import torch
import json
import numpy as np
import tiktoken

from gpt_model import GPTModel
from sparse_auto_encoder import SparseAutoencoder

# %%
device = "cpu"
GPT_CONFIG_124M = {
    "vocab_size": 50257,
    "context_length": 256,
    "emb_dim": 768,
    "n_heads": 12,
    "n_layers": 12,
    "drop_rate": 0.2,
    "qkv_bias": True,
    "device": "cpu",
}

# %%
model = GPTModel(GPT_CONFIG_124M)
checkpoint = torch.load("model_768_12_12_old_tok.pth", weights_only=True, map_location=torch.device('cpu'))

model.load_state_dict(checkpoint["model_state_dict"])
model.to(device)
model.eval();

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
sae_6 = SparseAutoencoder(input_dim=768, hidden_dim=3072).to(device)
sae_6.load_state_dict(torch.load("sae_model_6_3072.pth", map_location=torch.device('cpu')))
sae_6.eval();

sae_12 = SparseAutoencoder(input_dim=768, hidden_dim=3072).to(device)
sae_12.load_state_dict(torch.load("sae_model_12_3072.pth", map_location=torch.device('cpu')))
sae_12.eval();

# %%
def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

# %%
def get_token_embeddings(text, model, tokenizer, layers=[6, 12]):
    """
    Extracts token embeddings from specified transformer layers.

    Args:
    - text (str): Input text.
    - model: Custom GPT model.
    - tokenizer: tiktoken encoding object.
    - layers (list): Transformer layers to extract embeddings from.

    Returns:
    - dict: Layer-wise token embeddings {layer_number: embeddings}
    """

    input_ids = text_to_token_ids(text, tokenizer).to(device)

    with torch.no_grad():
        _, hidden_states = model(input_ids, output_hidden_states=True)

    embeddings = {} 
    for layer in layers:
        if layer - 1 < len(hidden_states):
            embeddings[layer] = hidden_states[layer - 1].squeeze(0).cpu().numpy()
        else:
            print(f"⚠️ Warning: Layer {layer} is out of range (max index {len(hidden_states) - 1})")

    return embeddings

# %%
from collections import defaultdict

def find_top_activating_neurons(concept_to_texts, model, tokenizer, sae, get_token_embeddings, layer=6, top_k=5, device='cpu'):
    concept_top_neurons = {}

    for concept, sentences in concept_to_texts.items():
        print(f"Processing concept: {concept}")
        neuron_activation_counts = defaultdict(int)
        total_tokens = 0

        for sentence in sentences:
            embeddings_np = get_token_embeddings(sentence, model, tokenizer, layers=[layer])[layer]
            embeddings = torch.tensor(embeddings_np, dtype=torch.float32).to(device)

            decoded, encoded = sae(embeddings)  # encoded shape: (seq_len, n_features)
            top_neuron_indices = torch.argmax(encoded, dim=1).cpu().numpy()

            for idx in top_neuron_indices:
                neuron_activation_counts[idx] += 1

            total_tokens += encoded.shape[0]

        neuron_avg_activation = {k: v / total_tokens for k, v in neuron_activation_counts.items()}
        top_neurons = sorted(neuron_avg_activation.items(), key=lambda x: x[1], reverse=True)[:top_k]
        concept_top_neurons[concept] = [neuron for neuron, _ in top_neurons]

    return concept_top_neurons

# %%
with open("concepts_to_text.json", "r", encoding="utf-8") as f:
    concept_to_texts = json.load(f)

top_neurons = find_top_activating_neurons(
    concept_to_texts=concept_to_texts,
    model=model,
    tokenizer=tokenizer,
    sae=sae_6,
    get_token_embeddings=get_token_embeddings,
    layer=6,
    top_k=5,
    device='cpu'
)

print(top_neurons)
# Out:
# Processing concept: marriage_as_duty
# Processing concept: romantic_love
# Processing concept: social_class
# Processing concept: moral_superiority
# Processing concept: stigma_of_spinsterhood
# Processing concept: wealth_and_inheritance
# Processing concept: female_professions
# Processing concept: male_professions
# Processing concept: reputation_and_gossip
# Processing concept: truth_and_honesty
# Processing concept: vanity_and_appearance
# Processing concept: matchmaking_positive
# Processing concept: matchmaking_negative
# Processing concept: social_hierarchy
# {'marriage_as_duty': [np.int64(720), np.int64(639), np.int64(2899), np.int64(1996), np.int64(2268)], 'romantic_love': [np.int64(720), np.int64(1091), np.int64(639), np.int64(1313), np.int64(1228)], 'social_class': [np.int64(720), np.int64(1996), np.int64(1080), np.int64(639), np.int64(779)], 'moral_superiority': [np.int64(1080), np.int64(1091), np.int64(2899), np.int64(639), np.int64(443)], 'stigma_of_spinsterhood': [np.int64(1080), np.int64(639), np.int64(1313), np.int64(317), np.int64(811)], 'wealth_and_inheritance': [np.int64(720), np.int64(1313), np.int64(604), np.int64(1091), np.int64(2604)], 'female_professions': [np.int64(779), np.int64(1441), np.int64(720), np.int64(2604), np.int64(5)], 'male_professions': [np.int64(779), np.int64(1441), np.int64(720), np.int64(2755), np.int64(2604)], 'reputation_and_gossip': [np.int64(2755), np.int64(720), np.int64(1441), np.int64(1313), np.int64(443)], 'truth_and_honesty': [np.int64(720), np.int64(2755), np.int64(1091), np.int64(1313), np.int64(639)], 'vanity_and_appearance': [np.int64(720), np.int64(2755), np.int64(2248), np.int64(2604), np.int64(2268)], 'matchmaking_positive': [np.int64(720), np.int64(2755), np.int64(1441), np.int64(2604), np.int64(779)], 'matchmaking_negative': [np.int64(2755), np.int64(720), np.int64(1441), np.int64(1313), np.int64(1091)], 'social_hierarchy': [np.int64(720), np.int64(1441), np.int64(2755), np.int64(639), np.int64(1996)]}

# %%
idx = text_to_token_ids("he is", tokenizer).to(device)
    
for _ in range(15):
    idx_cond = idx[:, -GPT_CONFIG_124M['context_length']:]

    # 1. Run forward to get hidden state at layer 6
    _, hiddens = model(idx_cond, output_hidden_states=True)
    layer6_hidden = hiddens[5].detach().clone()

    # 2. Inject neuron 720 with a high value
    layer6_hidden[:, :, 490] += 50.0  # boost neuron 720 activation

    # 3. Run from layer 6 onward using intervene_layer=6
    logits = model(
        idx_cond,
        intervene_layer=6,
        edited_hidden=layer6_hidden,
        output_hidden_states=False
    )
    idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)
    idx_next = idx_next[:, -1, :]

    # Same as before: append sampled index to the running sequence
    idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

    ouput_text = token_ids_to_text(idx, tokenizer)

# %%
ouput_text
# Out:
# 'he is a great deal of a great deal of the world. I am not to'

# %%
idx = text_to_token_ids("Marriage is", tokenizer).to(device)
boost_value = 5.0
layer = 6
    
for _ in range(10):
    with torch.no_grad():
        _, hidden_states = model(idx, output_hidden_states=True)
        layer_hidden = hidden_states[layer - 1].squeeze(0)

        intervened_hidden = sae_12.intervene_and_decode(layer_hidden, 1090, boost=5)

#         encoded[:, 2899] += boost_value

#         intervened_hidden = sae_6.decoder(encoded)
#         intervened_hidden = intervened_hidden.unsqueeze(0)  # shape: (batch, seq_len, emb_dim)

        logits = model(idx, intervene_layer=(layer - 1), edited_hidden=intervened_hidden.unsqueeze(0))
        logits = logits[:, -1, :]

#         # Filter logits with top_k sampling
#         top_logits, _ = torch.topk(logits, 50)
#         min_val = top_logits[:, -1]
#         logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)

#         # temperature scaling
#         logits = logits / 0.3

#         # Apply softmax to get probabilities
#         probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)

#         # Sample from the distribution
#         idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)

        idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)


        # Same as before: append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

        ouput_text = token_ids_to_text(idx, tokenizer)
        
ouput_text
# Out:
# 'Marriage is parallels\nanthafield Parkynch Hallrietriet'

# %%
import pandas as pd
from itertools import product
import csv
import os

def perform_causal_intervention(
    model,
    sae,
    tokenizer,
    neuron_indices,
    layer_idx,
    context_length,
    generate_steps=15,
    save_path="casual_int.csv",
    temp=0.0,
    topK=None
):
    boost_values = [0, 5, 10, 50, 100, 150, 200, 300]
    prompts = ["Marriage is", "he is", "she is", "the house"]

    headers = ["neuron", "prompt"] + [f"boost_{b}" for b in boost_values]
    results = []
    
    # Initialize file with headers if not already present
    if save_path and not os.path.exists(save_path):
        with open(save_path, "w", newline='', encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=headers)
            writer.writeheader()

    for neuron_id, prompt in product(neuron_indices, prompts):
        row = {"neuron": neuron_id, "prompt": prompt}

        for boost in boost_values:
            idx = text_to_token_ids(prompt, tokenizer).to(model.tok_emb.weight.device)

            for _ in range(generate_steps):
                idx_cond = idx[:, -context_length:]
                _, hidden_states = model(idx_cond, output_hidden_states=True)
                layer_hidden = hidden_states[layer - 1].squeeze(0)
        
                intervened_hidden = sae.intervene_and_decode(layer_hidden, neuron_id, boost=boost)
                
                logits = model(idx, intervene_layer=(layer - 1), edited_hidden=intervened_hidden.unsqueeze(0))
                logits = logits[:, -1, :]

                if temp > 0 and topK is not None:
                    # Filter logits with top_k sampling
                    top_logits, _ = torch.topk(logits, 50)
                    min_val = top_logits[:, -1]
                    logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)
            
                    # temperature scaling
                    logits = logits / 0.3
            
                    # Apply softmax to get probabilities
                    probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)
            
                    # Sample from the distribution
                    idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)
                else: 
                    idx_next = torch.argmax(logits, dim=-1, keepdim=True)
                    
                idx = torch.cat((idx, idx_next), dim=1)

            output_text = token_ids_to_text(idx, tokenizer)
            row[f"boost_{boost}"] = output_text

        results.append(row)
        with open(save_path, "a", newline='', encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=headers)
            writer.writerow(row)
        
    return pd.DataFrame(results)

# %%
neuron_indices = [6,22,29,35,46,69,90,113,142,205,209,240,241,272,
                  317,332,345,350,451,454,464,476,491,571,612,619,
                  637,643,663,698,714,723,731,779,804,814,837,860,
                  885,888,906,915,942,945,961,987,994,1021,1029,1033,
                  1078,1080,1091,1101,1104,1108,1116,1136,1156,1190,
                  1231,1251,1264,1277,1318,1322,1332,1350,1355,1410,
                  1426,1440,1441,1450,1477,1505,1531,1545,1553,1596,
                  1670,1704,1707,1743,1768,1783,1801,1807,1812,1840,
                  1882,1885,1894,1929,1931,1962,1979,1996,2000,2002,
                  2003,2118,2159,2173,2186,2227,2238,2248,2263,2268,
                  2291,2308,2344,2347,2362,2371,2375,2378,2396,2473,
                  2514,2522,2526,2545,2546,2562,2577,2585,2604,2649,
                  2691,2693,2697,2713,2718,2735,2755,2764,2795,2813,
                  2833,2861,2870,2875,2930,2941,3017,3030,3057,3062]

perform_causal_intervention(model, sae_6, tokenizer, neuron_indices, layer_idx=6, context_length=GPT_CONFIG_124M['context_length'], generate_steps=15)
# Out:
#      neuron       prompt                                            boost_0  \
# 0         6  Marriage is  Marriage is not practitionerityity? practition...
# 1         6        he is  he is practitioner practitioner practitioner p...
# 2         6       she is  she is practitioner practitioner practitioner ...
# 3         6    the house  the housekeeper practitioner practitioner prac...
# 4        22  Marriage is  Marriage is not practitionerityity? practition...
# ..      ...          ...                                                ...
# 595    3057    the house  the housekeeper practitioner practitioner prac...
# 596    3062  Marriage is  Marriage is not practitionerityity? practition...
# 597    3062        he is  he is practitioner practitioner practitioner p...
# 598    3062       she is  she is practitioner practitioner practitioner ...
# 599    3062    the house  the housekeeper practitioner practitioner prac...
#
#                                                boost_5  \
# 0    Marriage is not practitionerityity? practition...
# 1    he is practitioner practitioner practitioner p...
# 2    she is practitioner practitioner practitioner ...
# 3    the housekeeper practitioner practitioner prac...
# 4    Marriage is not practitionerityity? practition...
# ..                                                 ...
# 595  the housekeeper practitioner practitioner prac...
# 596  Marriage is not practitionerityity? practition...
# 597  he is practitioner practitioner practitioner p...
# 598  she is practitioner practitioner practitioner ...
# 599  the housekeeper practitioner practitioner prac...
#
#                                               boost_10  \
# 0    Marriage is not practitionerityity? practition...
# 1    he is practitioner practitioner practitioner p...
# 2    she is practitioner practitioner practitioner ...
# 3    the housekeeper practitioner practitioner prac...
# 4    Marriage is not practitionerityity? practition...
# ..                                                 ...
# 595  the housekeeper practitioner practitioner prac...
# 596  Marriage is not practitionerityity? practition...
# 597  he is practitioner practitioner practitioner p...
# 598  she is practitioner practitioner practitioner ...
# 599  the housekeeper practitioner practitioner prac...
#
#                                               boost_50  \
# 0    Marriage is not practitionerityity? secondsst ...
# 1    he is practitioner practitioner practitioner p...
# 2    she is practitioner practitioner practitioner ...
# 3    the housekeeper practitioner practitioner prac...
# 4    Marriage is not practitionerity thatity that b...
# ..                                                 ...
# 595  the housekeeper practitioner practitioner prac...
# 596  Marriage is not practitionerityity? practition...
# 597  he is practitioner practitioner practitioner p...
# 598  she is practitioner practitioner practitioner ...
# 599  the housekeeper practitioner practitioner prac...
#
#                                              boost_100  \
# 0    Marriage is not practitionerityity? secondsst ...
# 1    he is practitioner practitioner practitioner p...
# 2    she is practitioner practitioner practitioner ...
# 3    the housekeeper practitioner practitioner prac...
# 4    Marriage is not been practitioner to practitio...
# ..                                                 ...
# 595  the housekeeper practitioner practitioner prac...
# 596  Marriage is practitioner practitioner practiti...
# 597  he is practitioner practitioner practitioner p...
# 598  she is practitioner practitioner practitioner ...
# 599  the housekeeper practitioner practitioner prac...
#
#                                              boost_150  \
# 0    Marriage is not practitionerityity? secondsst ...
# 1    he is practitioner practitioner practitioner p...
# 2    she is practitioner practitioner practitioner ...
# 3    the housekeeperlarge practitionerlargeity? sec...
# 4    Marriage is not been toity that beenppercross ...
# ..                                                 ...
# 595  the housekeeper practitioner practitioner prac...
# 596  Marriage is practitioner practitioner practiti...
# 597  he is practitioner practitioner practitioner p...
# 598  she is practitioner practitioner practitioner ...
# 599  the housekeeper practitioner practitioner prac...
#
#                                              boost_200  \
# 0    Marriage is not practitionerity? seconds secon...
# 1    he is practitioner practitioner practitioner p...
# 2    she is practitionerlargeityablylargeityably pr...
# 3    the housekeeperlarge practitionerlargeityshire...
# 4    Marriage is not been toity that been that been...
# ..                                                 ...
# 595  the housekeeper practitioner practitionershire...
# 596  Marriage is practitioner practitioner practiti...
# 597  he is practitioner practitioner practitioner p...
# 598  she is practitioner practitioner practitioner ...
# 599  the housekeeper practitioner practitioner prac...
#
#                                              boost_300
# 0    Marriage is not practitionerityshire? secondsu...
# 1    he is practitionerlargeityablylargeuringstures...
# 2    she islarge tolargeity?st secondsures tolargei...
# 3    the housekeeperlarge agreements agreements agr...
# 4    Marriage is not been vain to that that that th...
# ..                                                 ...
# 595  the housekeeper practitionershiresshire?shirei...
# 596  Marriage is practitioner practitioner practiti...
# 597  he is practitioner practitioner practitioner p...
# 598  she is practitioner practitioner practitioner ...
# 599  the house practitioner practitioner practition...
#
# [600 rows x 10 columns]

# %%
# redo with temp and topk
neuron_indices = [22, 35, 90, 205, 240, 272, 332, 451, 612, 619, 643, 779, 814, 1078,
                  1080, 1264, 1355, 1553, 1894, 1929, 1996, 2002, 2173, 2238, 2268,
                  2362, 2473, 2546, 2562, 2755, 2870, 2941]

perform_causal_intervention(model, sae_6, tokenizer, neuron_indices, layer_idx=6,
                            context_length=GPT_CONFIG_124M['context_length'],
                            generate_steps=15, save_path="casual_int_temp_topk.csv",
                            temp=0.1, topK=50)
# Out:
#      neuron       prompt                                            boost_0  \
# 0        22  Marriage is  Marriage is Artifact to landsl enormouslyity f...
# 1        22        he is  he is okay to corpus Survivor yourself that be...
# 2        22       she is  she isPic defends Savage to lesbianst Chimerae...
# 3        22    the house  the house aginginskyiciochatgeneratedets McCl ...
# 4        35  Marriage is  Marriage is rhably.......ity? defends to pract...
# ..      ...          ...                                                ...
# 123    2870    the house  the houseCongressets Dude ArtifactBufferityshi...
# 124    2941  Marriage is  Marriage is defends been briefing recognizesf ...
# 125    2941        he is  he isamas practitioner Judd Artifact Juddures ...
# 126    2941       she is  she is VIDE enormously to resemb seconds me? F...
# 127    2941    the house  the house anti overdoseGalures to252fox thatas...
#
#                                                boost_5  \
# 0    Marriage is seconds tolarge that resembensions...
# 1    he isinskyasuresInfst252ures tolargeingsityity...
# 2    she isamasCur practitionereness Comicets252 th...
# 3    the housekeeper suspic Handbook contin Request...
# 4    Marriage is seconds banned duringity themiasco...
# ..                                                 ...
# 123  the house GO Israelichat Artifact resemb agree...
# 124  Marriage is Luffy okayity?stasuresbrance to de...
# 125  he is252idential briefing practitionerchatabil...
# 126  she is practitioner rh Chevy defends Sports Mc...
# 127  the house88chatimb briefing recognizesgovernme...
#
#                                               boost_10  \
# 0    Marriage is driven practitioner been contin by...
# 1    he is Sports Comicchatingity?largeityfield Coa...
# 2    she islargeenesschatablylargeful schemast252st...
# 3    the house agingommelablyMartinlargeets continc...
# 4    Marriage isPic practitioner to briefing Debora...
# ..                                                 ...
# 123  the houseamas contin Poe Kidd overdose briefin...
# 124  Marriage is not Coaststf Comic to hitters sche...
# 125  he isrising Sportsmodel of secondsst uint to u...
# 126  she is practitioner Until """ practitionerlarg...
# 127  the housekeeping uintjumpures apprenticechat n...
#
#                                               boost_50  \
# 0    Marriage is not Artifact toasuresetsfFlag been...
# 1    he is CONCCur makeshift to Shawets McClity for...
# 2    she is252 practitioner that makeshift togi 194...
# 3    the house banned recognizeschat practitioner A...
# 4    Marriage is not to corpus thatshire?chat drive...
# ..                                                 ...
# 123  the house defends McCl practitioner posting Fu...
# 124  Marriage isPic banned to overdoselaughter88801...
# 125  he isrising washchat them demos timberfIGHTS t...
# 126  she isrisingriet pilgrommelity that landsl pra...
# 127  the house Coast Deborahf Wrapchatfoxgenerateds...
#
#                                              boost_100  \
# 0    Marriage is to secondsity thatrupulousity? sec...
# 1    he isicio to LC been Coast?st? seconds thatity...
# 2    she is not been practitionershiresom them seco...
# 3    the housekeeperlarge to briefing thatitating d...
# 4    Marriage is not beenshire toity thatity that s...
# ..                                                 ...
# 123  the house inflammatory crises Artifact resemb ...
# 124  Marriage is notrising to continity thatrisingu...
# 125  he is Fiorina./stshirefoxitatingity to Savage ...
# 126  she is252 Instrumentfamaslargeity" practitione...
# 127  the house Europeanben to lesbian seconds pract...
#
#                                              boost_150  \
# 0    Marriage is exactlyPicity that norietent been ...
# 1    he is earlyity that beenynchitating to Comic t...
# 2    she isimb to Instrument nothing enormously tha...
# 3    the housekeeper practitioner practitioneritati...
# 4    Marriage is not been any what them that no goo...
# ..                                                 ...
# 123  the housekeeper crises colleagues athleticgene...
# 124  Marriage is not resemb yourself to deepeningOR...
# 125  he is FiorinafatherGal to secondsst Comicity?l...
# 126  she is Judd Artifact Stealth topolice baskets ...
# 127  the house Deborah Savageityflarge not252 to at...
#
#                                              boost_200  \
# 0    Marriage is that noriet that thateryenance tha...
# 1    he is to Sports thatitating beenppercross to S...
# 2    she is practitioner that nothing thatitatingit...
# 3    the housekeepinglarge whichity been banned toi...
# 4    Marriage is that such an hour that that that t...
# ..                                                 ...
# 123  the house Borders ArtifactFlagfANGE Princess D...
# 124  Marriage is not Artifact howfoxfather that サーテ...
# 125  he is not resemb Fiorina perpetratedlargeably ...
# 126  she is CONC explosivesDC through makeshift? no...
# 127  the houseا yourself opiof athletic toCongress?...
#
#                                              boost_300
# 0    Marriage is not that that that time that which...
# 1    he is nothing to banned that that been vain re...
# 2    she is to that been vain toriet that time toit...
# 3    the housekeeper beenynated toity that that tim...
# 4    Marriage is hisity that something being his be...
# ..                                                 ...
# 123  the house contin cornerstone briefing Cait inc...
# 124  Marriage is not Deborah baskets toCongress you...
# 125  he is not explosives you overdose interstellar...
# 126  she is openerouls explosives you resemb themla...
# 127  the housekeeper pilgr Artifact them resemb you...
#
# [128 rows x 10 columns]

# %%
# redo with temp and topk
neuron_indices = [491, 571, 649, 814, 984, 1410, 1440, 1596, 1768, 1929, 1979, 2649, 2691]

perform_causal_intervention(model, sae_6, tokenizer, neuron_indices, layer_idx=6,
                            context_length=GPT_CONFIG_124M['context_length'],
                            generate_steps=15, save_path="casual_in_6_special_neurons.csv",
                            temp=0.2, topK=30)
# Out:
#     neuron       prompt                                            boost_0  \
# 0      491  Marriage is  Marriage isasures? banned to Demand demosshire...
# 1      491        he is  he isrising secondsesanity thatchatMartinst Sh...
# 2      491       she is  she is practitioner tiityitating secondsably p...
# 3      491    the house  the houselarge practitioner Appeal Tau resembc...
# 4      571  Marriage is  Marriage is not opio to Shawfield contin toris...
# 5      571        he is  he is practitionerasures Savagef okay to demos...
# 6      571       she is  she is practitioner Judd European been schema ...
# 7      571    the house  the housemaids88 seconds tunnels?inskyitylessl...
# 8      649  Marriage is  Marriage is to makeshift resemb Artifact to en...
# 9      649        he is  he isfox seconds toasures tolargeityity to cri...
# 10     649       she is  she is252 Instrument practitioneritatingity th...
# 11     649    the house  the house88 Deborah McClityshire Yugoslavia ex...
# 12     814  Marriage is  Marriage is notrisingity Courcy practitionerit...
# 13     814        he is  he is Comic seconds to uintrietBuffer constitu...
# 14     814       she is  she iszza been recognizesityably practitioneri...
# 15     814    the house  the house JournalGalitatings lesbianitatingcha...
# 16     984  Marriage is  Marriage is to secondsity?st bannedstchatably ...
# 17     984        he is  he is Messages practitioner practitionerityity...
# 18     984       she is  she isRevolution Stealth to inclusion Survivor...
# 19     984    the house  the houseANGE opiochat practitionerchatrising ...
# 20    1410  Marriage is  Marriage is Luffy Blossom toTile people torisi...
# 21    1410        he is  he isfox practitioner practitionerity? spectra...
# 22    1410       she is  she is practitionerBuffer Artifactst McClimb k...
# 23    1410    the house  the houseCongress pilgrWorkets overdose overdo...
# 24    1440  Marriage is  Marriage isFlagst angrilyfox to abdomenityshir...
# 25    1440        he is  he isogene practitioner deepeningenance toesan...
# 26    1440       she is  she is CONC seconds practitioner Artifact toch...
# 27    1440    the house  the house CoastANGE been252itatingity? caution...
# 28    1596  Marriage is  Marriage is not Sports defendschatshireommelit...
# 29    1596        he is  he is practitioner seconds252stures torisingen...
# 30    1596       she is  she iszza?252,... CONC reliesetsf practitioner...
# 31    1596    the house  the house Borders Yugoslavia okaysInff Vote to...
# 32    1768  Marriage is  Marriage is Savage to practitioner Untility th...
# 33    1768        he is  he is practitionerGal secondsstlargeenanceshir...
# 34    1768       she is  she is252 seconds them Instrumentshiref practi...
# 35    1768    the house  the houselarge practitioner=>largeity that Xie...
# 36    1929  Marriage is  Marriage isinskystgenerated early to tiity tha...
# 37    1929        he is  he is Handbooklargeityst252 secondsably801ably...
# 38    1929       she is  she is pilgrbenily252ride referen seconds them...
# 39    1929    the house  the housekeeper practitioner ArtifactANGE Dept...
# 40    1979  Marriage is  Marriage is not practitionerityityitybourn ear...
# 41    1979        he is  he is Fiorina banned to Instrumentr European s...
# 42    1979       she is  she is inclusionrisingchatably Ninthitatinglyc...
# 43    1979    the house  the houseamas practitioner サーティriet practition...
# 44    2649  Marriage is  Marriage is explosivesity?imbenesslargeity ban...
# 45    2649        he is  he is defendschat Artifact pilgr Artifact driv...
# 46    2649       she is  she is Fiorinaabilityasures forgotten practiti...
# 47    2649    the house  the house European Buzz Comicity seconds opio?...
# 48    2691  Marriage is  Marriage is to=>ity?imb that portrayed,... Deb...
# 49    2691        he is  he is agreementsasures okayenessstormfield Com...
# 50    2691       she is  she is Sports to resembgovernment to landsl Co...
# 51    2691    the house  the housekeeperlargefox1985largeityshire:chatg...
#
#                                               boost_5  \
# 0   Marriage is to Sports to InstrumentfRangeeness...
# 1   he isfoxasuresgovernmentchatesanuresity that C...
# 2   she is explosives briefing Comic tofoxfieldgen...
# 3   the house agreements uint=> ti practitionerInf...
# 4   Marriage isogene seconds that Chimera Cour Jam...
# 5   he isasures to Instrumentablylargeity that Wra...
# 6   she isfox to practitionerCurBufferityf defends...
# 7   the house546benshire CONCIGHTS practitionerBuf...
# 8   Marriage islarge been hitters practitioner def...
# 9   he is practitionerBuffer celebrateschatgenerat...
# 10  she is practitioner Savage thatitatingityably ...
# 11  the houseANGEgenerated hitterslargeity? Europe...
# 12  Marriage isasures to hittersIGHTSst LCshireCur...
# 13  he is603=>398itatings that hypothetical McCl b...
# 14  she is procedures togi Chevylargeets? seconds ...
# 15  the house inflammatorylargeity? Yugoslaviachat...
# 16  Marriage is not Artifact landsl toophobia clin...
# 17  he is practitioner Savage practitionerasures c...
# 18  she islargefather to resemb CONCBuffer Instrum...
# 19  the housekeeper practitioner hittersgenerated ...
# 20  Marriage is not recognizesitatingity? seconds ...
# 21  he is CONC pilgr RIPity withchat252 sincechati...
# 22  she is practitioner252 opener Cour Comicily ba...
# 23  the housekeeperassad European demos banned tha...
# 24  Marriage is Luffy practitionermine criseschata...
# 25  he isicioasureslarge torising how practitioner...
# 26  she is Caitommelityity? timber secondschatgove...
# 27  the houseNeed schema McCl88 aviationInf ones b...
# 28  Marriage is practitioner thatitatingity?largei...
# 29  he is practitioner ti Comicfield selectsTileur...
# 30  she is practitioner Artifact Sports Shawfield ...
# 31  the housefox banned SurvivorLeave seconds tori...
# 32  Marriage is doctr practitioner timberfFactory ...
# 33  he is doctr banned tochatity? Cait practitione...
# 34  she is,... Artifact defends themlarge them Jam...
# 35  the house explosivesride Artifactings252 overd...
# 36  Marriage is not been hype extracts togiity tha...
# 37  he is603 Artifactlargestidentialifyingstfbenf ...
# 38  she isfox to makeshift thatIGHTS? Instrumentch...
# 39  the housekeeper contin Coastimbrisinguring pra...
# 40  Marriage is McCl Yugoslaviashirefox that secon...
# 41  he isasures that UEably Survivoritating second...
# 42  she is enormouslylarge to ChevyInfstimbity tha...
# 43  the house88 aging practitionerlarge Cour pract...
# 44  Marriage is ArtifactFlagst schemaablyasures fo...
# 45  he is Luffy banned pilgr tolargefield practiti...
# 46  she is doctr contin Sportsity thatIGHTSlargeit...
# 47  the houseasures rh resemb procedures to demos ...
# 48  Marriage is practitioner Artifact pilgr Europe...
# 49  he is Advis,... secondsst Yaleasures to Surviv...
# 50  she is weldshire McClity?shireBuffer to tiity?...
# 51  the houseNeed resemb practitioner Artifact MDM...
#
#                                              boost_10  \
# 0   Marriage isommel to ICCfammedf,... banned to h...
# 1   he is practitioner Judd.....large to banned to...
# 2   she is procedures to briefingst beenMartin? wa...
# 3   the housekeeping demos Wrap secondsinskychatsh...
# 4   Marriage is notamas? Furyshire tofox Handbook ...
# 5   he islargef Bachelorably practitionerity?st th...
# 6   she is banned tolargeity?stchatity to Comicfie...
# 7   the houseNeed resemb aging banned to agreement...
# 8   Marriage isrising?foxgenerated to practitioner...
# 9   he is banned to�� to ICCily predecessorslessly...
# 10  she is banned to abdomenity seconds seconds pr...
# 11  the house okay252ommelshirebourn?fFactoryshire...
# 12  Marriage is notrising practitioner pilgr to Sa...
# 13  he is Kidd to abdomen Cour Dept been practitio...
# 14  she isinsky resembPic to ICCily uint been88 to...
# 15  the house banned briefinginsky drivenMartinshi...
# 16  Marriage is not colleaguesityity for secondsst...
# 17  he is banned to deepening uint uintitating Cou...
# 18  she is inclusion recognizes timber seconds sch...
# 19  the housekeeper practitioner Cookebenimb Journ...
# 20  Marriage is practitioner pilgr practitioner to...
# 21  he islarge extractschatably Bachelor toTileity...
# 22  she is practitioner demos Buzz pilgr Trends be...
# 23  the house False....... resemb practitioner Coa...
# 24  Marriage isPic agingity:st okaychat practition...
# 25  he islarge Courcy explosivesityably practition...
# 26  she isfox banned tochatlargeityfieldensions to...
# 27  the housefox recognizesshire Cit,...idential m...
# 28  Marriage isasuresiblyity that Cait practitione...
# 29  he is weldogene okayeness Artifact earlyures t...
# 30  she is practitionerlargeityably location252 se...
# 31  the house deepening Sports Comic away briefing...
# 32  Marriage isamas practitionerityityably banneda...
# 33  he is LuffyPic practitioner seconds Comicity!B...
# 34  she islargeity that Wrap Comic toasures during...
# 35  the house overdose ICC practitioner Sports Req...
# 36  Marriage isommelityably practitionericity tola...
# 37  he isasureslargeity thatrising Courcychat prac...
# 38  she isfox to Juddity:Sel Trends seconds practi...
# 39  the house 194932giamas Deborah practitioner Co...
# 40  Marriage is not Sportseness enormouslyity? opi...
# 41  he islargeity away to Savage toPic TAGablyasur...
# 42  she islarge tolargeets recognizesf uintity tol...
# 43  the house Wrap ✔ Ventura that practitioner252c...
# 44  Marriage isityity them practitioner McCl pract...
# 45  he is athleticf practitioner practitioner Unti...
# 46  she is celebrates? defends them practitioner p...
# 47  the housekeeperlarge athleticity Courcy Savage...
# 48  Marriage is Luffy deepeningpie demosenessPicib...
# 49  he is practitioner practitioner john seconds s...
# 50  she is Fiorinalessly398 practitionerity to pra...
# 51  the housekeeper,... practitioner seconds pract...
#
#                                              boost_50  \
# 0   Marriage is nothing enormously Chevylarge to h...
# 1   he is Artifact Sports enormouslyst�� to briefi...
# 2   she isrisingimbchatingity tolargefasu that bri...
# 3   the house agreements McCl Chimera briefing bri...
# 4   Marriage is not weld explosivesityityity that ...
# 5   he isasures that88father Artifact Ninth schema...
# 6   she isasures to banned to briefingst investmen...
# 7   the houseamaschat agreements practitioner=>oge...
# 8   Marriage isamasGaleness Artifactchating extrac...
# 9   he is practitionerlarge tochat recognizesitati...
# 10  she is weld tomodel by seconds to abdomen sinc...
# 11  the house contin practitioner SavageCur MDMAit...
# 12  Marriage is aging practitioner to LC practitio...
# 13  he is88 to��ratchatity awayst Comicingsinskyan...
# 14  she isfox trousersInf to Juddr RIP practitione...
# 15  the housekeeper MDMA801generated oversight? op...
# 16  Marriage is practitionerityably Messagesitatin...
# 17  he is practitioner practitioner Sports Dept pr...
# 18  she isinskyommel beeninskyingsinskystgenerated...
# 19  the house defends Journal Savageibly practitio...
# 20  Marriage is not deepeningity to opio thatident...
# 21  he isFlag been landsl tolargeity: timber overd...
# 22  she is Fiorina to Comicst McCl to banned to br...
# 23  the houselarge practitioner=> briefing practit...
# 24  Marriage isNightIGHTS to LC overdose practitio...
# 25  he is explosivesmodelchatingity thatchat pract...
# 26  she is weld Comic tolargefield practitioner Xi...
# 27  the housegenerated hitters opiofenvironment ag...
# 28  Marriage is notrisingf European that beenWork ...
# 29  he isamas practitioner practitionereness Xiest...
# 30  she is 199 Instrumentf resemb practitioner the...
# 31  the houseCongressCur demos CONC practitioner? ...
# 32  Marriage isrisingst: overdose 115 pilgr practi...
# 33  he is practitioner Savage briefingst252 practi...
# 34  she is Fiorinalessly practitioner252 Shawfield...
# 35  the house Vivflargeityets uint to recognizes o...
# 36  Marriage isity secondsbourn toasuresets collea...
# 37  he is,...generatedfox that Sports Xieshirebour...
# 38  she isamas practitioner Comicfieldity that hyp...
# 39  the house JournalFlag practitionerCur agreemen...
# 40  Marriage is notchatityity? spectral early to p...
# 41  he is seconds that briefingityifyingity tolarg...
# 42  she islarge to252stetsst to procedures tolarge...
# 43  the housekeeperlarge thatifyingity?finsky been...
# 44  Marriage is notfox that postingence basketsity...
# 45  he is agreements okay recognizesfANGE been252c...
# 46  she is Savage to practitioneritychatommel to u...
# 47  the house Journal resembamas Comic practitione...
# 48  Marriage islargest been bannedst252st Sportsch...
# 49  he is CONC resembPicgeneratedimbings Comicitat...
# 50  she is Savage to Instrument torisingence togi ...
# 51  the houseGalets,... repatriets repatrishire or...
#
#                                             boost_100  \
# 0   Marriage is toommel to proceduresity awayst? p...
# 1   he is603 pilgr pilgrsomest to deepening to col...
# 2   she is celebrates sincerising to Savagef uintr...
# 3   the houseophobia crisesSold briefing entities ...
# 4   Marriage is notommelity quite Fury to uint toe...
# 5   he isFlagf Trendsf practitioner?st seconds tog...
# 6   she is Handbook practitioner Coastets to hitte...
# 7   the housekeeperCongress to demos themstshireil...
# 8   Marriage isFlagsturesings?st thatlargeitatings...
# 9   he is practitioner practitioner Sports Deborah...
# 10  she isasures to=>Pic Cour./st thatstchatshire?...
# 11  the housekeeperfoxaspers okay pilgrffoxably pr...
# 12  Marriage is not been McClity with landsl to re...
# 13  he is tideals to hypeInfst Yale practitioner o...
# 14  she is briefing=> Judditating to88stgenerated ...
# 15  the house proceduresshireamas institution comb...
# 16  Marriage is resemb Sports enormously practitio...
# 17  he is okay okayitatingstchatably Deborah pract...
# 18  she is weld schemaably okayably schemaably ban...
# 19  the housekeeper252ommelchatinskyshirelargeious...
# 20  Marriage is aginglylarge toophobiashirest enor...
# 21  he islarge to Survivorst pilgr tolargeenance t...
# 22  she isommel to practitionerlessly LC to predec...
# 23  the house defends LC ti Lorenommel away�� to88...
# 24  Marriage is not practitioner Courcy decreasing...
# 25  he is Messages beenGal torisingery practitione...
# 26  she isFlagstlargeity toesan Stealth schema pra...
# 27  the houseANGE seconds./hours recognizesf affid...
# 28  Marriage is colleaguesityably pilgrityity: tim...
# 29  he is./ not uintensions to seconds secondsity ...
# 30  she is Sports to briefingfieldshireity thatang...
# 31  the house overdose practitioner Bordersshire C...
# 32  Marriage is opener McCl aging seconds that cor...
# 33  he isamasgenerated�� notlargeity: Courcychat t...
# 34  she is pilgr Instrumentf uintasures to makeshi...
# 35  the houseamas MDMAamasshirelargeity tolargeets...
# 36  Marriage is nothing demosmine to ICC according...
# 37  he isBuffer defends Comicfieldshirefmobile tim...
# 38  she is Judd seconds252 intofieldshire to Judds...
# 39  the houseNeed pilgr celebrates thatIGHTSitatin...
# 40  Marriage is not toity that beenets to Savage t...
# 41  he is not toammed how to deepening that Courcy...
# 42  she is nothing been noity thatst tochatst that...
# 43  the housekeeper ICCshire to Juddop? orid to th...
# 44  Marriage isfoxst okay secondsst McClated toort...
# 45  he is agreements Deborah railingityablechat le...
# 46  she is,... Fiorina railingity secondsst okay t...
# 47  the house practitionerFlagshire Yalechatommell...
# 48  Marriage is not been overdose spectral: been o...
# 49  he is Fiorina tolargeity:etsst railinguredity ...
# 50  she is defends crises thatchatchatshire to oka...
# 51  the housemaid Aki LCchatfoxfield Instrumentita...
#
#                                             boost_150  \
# 0   Marriage is souls! practitioner to resemb prac...
# 1   he is MarxismBuffer?riet banned not been Sport...
# 2   she is pilgrimb to recognizesity of?chatrietas...
# 3   the housekeepersolidamasshireidential practiti...
# 4   Marriage is notliner to recognizesf landsl to ...
# 5   he is practitioner seconds away fromchating to...
# 6   she is not okay to opio to briefingstchatablya...
# 7   the housekeeper aviation Artifact given Courcy...
# 8   Marriage is not Instrument to252enceityably ma...
# 9   he is pilgrinsky been agreementsimb? secondsit...
# 10  she is athletic practitioner seconds? colleagu...
# 11  the housekeeper aviation Bordersshirefoxbourni...
# 12  Marriage is not=>imbamas to staffed them pilgr...
# 13  he is Savage toPic banned to lesbian resemb wh...
# 14  she is modular�� tolarge to procedures notitat...
# 15  the housegenerated MDMA252 enormously practiti...
# 16  Marriage isBuffergovernment early crises that ...
# 17  he is practitionerrising opiost seconds practi...
# 18  she is athletic practitioner=>largeity that Ca...
# 19  the house WrapBuffer Wrap practitionerimbommel...
# 20  Marriage isrising thatity ofst./ to deepening ...
# 21  he isrising Courcy practitionereness Journal s...
# 22  she is to briefing252 away?stchatshireCurietal...
# 23  the house anti seconds bannedlargeity given hi...
# 24  Marriage is enormously Comicity=> banned to co...
# 25  he is Messages demos SportsIS Sanctuary Cait88...
# 26  she is Comic Sports uint momentum banned./ pra...
# 27  the house explosivesPicaspers resembride crise...
# 28  Marriage is practitioner peoples secondsstures...
# 29  he isasures forgotten to crisesider people tog...
# 30  she is HandbookPic to okayity thatingity thati...
# 31  the housekeeper./shirevel Coastitating people ...
# 32  Marriage is seconds European been hypeilylarge...
# 33  he is athletic defendsCongressCur makeshiftzza...
# 34  she is Savage practitioner secondslargeity? ex...
# 35  the house overdoseBufferings MDMA demos defend...
# 36  Marriage is not been practitioner shownfieldPi...
# 37  he islargeenance tolargeably practitioner seco...
# 38  she ischat timberablylarge tolargeity: seconds...
# 39  the housekeeperasures explosivesshirejumpst Co...
# 40  Marriage is toity to?st thatity for what thati...
# 41  he is not been to that away fromets toity that...
# 42  she is not toity away thatity thatity to pligh...
# 43  the housekeeperity toesanity away toity to tha...
# 44  Marriage is Sports Xieablypie Reduced them pra...
# 45  he is Sportsinsky basketsInf to�� togiCongress...
# 46  she is Comiced secondsstimbgovernment what pil...
# 47  the house opiochaticio McCl�� to ICCetsPicInfs...
# 48  Marriage is timberityably Deborah torising tha...
# 49  he is continf practitioneritatingity thatamas:...
# 50  she is to crisesity? InstrumentityityiblyIGHTS...
# 51  the housekeeper defendsride practitioner secon...
#
#                                             boost_200  \
# 0   Marriage is not okay toTileity that?abilityrie...
# 1   he is HAL tomodel to Fiorina their?f Stuff how...
# 2   she is Artifact tolargestfflargeity to resemb ...
# 3   the housekeeperlargeful? pilgrf resemb to prac...
# 4   Marriage is not been Courcyitatingsst been giv...
# 5   he iszza thatasures givenchatshire not resemb ...
# 6   she isFlag to practitioner not to seconds forg...
# 7   the housekeeper angels 1949 practitioner pilgr...
# 8   Marriage is not okay fasthead been noity thati...
# 9   he is Advis nochatshire practitioner Coast the...
# 10  she is Sports to=>ings practitioner them pract...
# 11  the house deepening practitioner been252est th...
# 12  Marriage is not banned tolarge to Artifact to ...
# 13  he is notchat angels practitionerinskyimb to s...
# 14  she isrising togi Teen not escaped tochat quit...
# 15  the house Viv not beenasures gone aging to ban...
# 16  Marriage isfox bannedably okay recognizes spec...
# 17  he is Comic Savage252 Europeanures: defendslar...
# 18  she is...] bannedfoxenanceets practitioner Com...
# 19  the house uint lesbian opio toCongressimbNick ...
# 20  Marriage is not frig? practitioner? recognizes...
# 21  he is practitionerlargeity torising to practit...
# 22  she is practitioner to practitionerityineity t...
# 23  the housekeeper practitioner deepeningfoxfoxur...
# 24  Marriage is Sports practitioner Savage schema ...
# 25  he is VIDE valvesGal to predecessorsrisingride...
# 26  she isGalWork practitioner okay agreementsasur...
# 27  the house=> Comicgenerated hitters practitione...
# 28  Marriage is goneityityity people to lesbian pe...
# 29  he is./ that been agreements practitioner peop...
# 30  she is CONC to lesbianity men timberenessident...
# 31  the house Trendsity?shireity peoplefox people ...
# 32  Marriage isBufferiasco? enormously....... Euro...
# 33  he islarge Fiorina Handbook practitioner Fiori...
# 34  she is procedures that LC uint"}]," notchat we...
# 35  the houseIGHTS.......large252 secondschatlarge...
# 36  Marriage is whatrisingably Accounts? Courcycha...
# 37  he is Vivlarge to deepeningity that sort to ov...
# 38  she is bannedlargestimbflarge tolarge to brief...
# 39  the housekeeper ruth Corridorbourn'sity beenpp...
# 40  Marriage is to that to to that to that faultsi...
# 41  he is toity that toitating away?ity that toity...
# 42  she is over to them toures to them that faults...
# 43  the housekeeper to that to him toity that no t...
# 44  Marriage is Comicablyisec AdenfFlagstgenerated...
# 45  he is practitioner briefing practitioner Coast...
# 46  she isommel to Comic how Instrument at uint be...
# 47  the houseا been Vita Comic Sturf practitionerc...
# 48  Marriage is not practitionereness crisesfNeed ...
# 49  he is agingily Request:ityably BuzzFeedityures...
# 50  she is practitioner Artifact to deepening to L...
# 51  the housekeeper overdose spectralshireasureset...
#
#                                             boost_300
# 0   Marriage is not been forgotten awayings away w...
# 1   he is to Button beenasu to practitionered to L...
# 2   she is tolarge or themffhours to seconds to In...
# 3   the housekeeperalid them to aviationbourn away...
# 4   Marriage is notliner tozza to banned to303 fri...
# 5   he is undoubtedly to celebrates torising Courc...
# 6   she is not been Saskst not to demos tofox to r...
# 7   the housetchenance to Chevyid interview to lar...
# 8   Marriage is not Instrument beenrising to secon...
# 9   he is notammed beenamaschat been Greenpeaceita...
# 10  she is practitionerlargeabella injured themity...
# 11  the housekeeperbenitatingly practitioner early...
# 12  Marriage is gone demos to Survivor gone? timbe...
# 13  he is not been McCl quite Dept to axle no more...
# 14  she is not been Greenpeace sure to demos taunt...
# 15  the house Savage wash mes sureets informedenvi...
# 16  Marriage is Luffy schemaably pilgr customized ...
# 17  he islarge Yugoslavia Comicrat Combined trek s...
# 18  she is LuffyrisingBuffer practitioner Artifact...
# 19  the house practitioner Artifactilar opio pilgr...
# 20  Marriage is notamas visits not beenchatity to ...
# 21  he is practitioner Lic secondsures early toris...
# 22  she is not beenasuity given them away: howfox ...
# 23  the housekeeper practitioner coordin awayfox v...
# 24  Marriage is banned percentity=>ogeneMartin sig...
# 25  he isrideBuffer=> okay practitioner AppealPoli...
# 26  she is procedures toogenelargeride SportsIS pr...
# 27  the house aging=> highlighting McClride Slipri...
# 28  Marriage is people people people people people...
# 29  he is people people men people to uint people ...
# 30  she isityity people people people people peopl...
# 31  the housekeeper recognizes people peopleity pe...
# 32  Marriage is pilgr makeshift サーティ pilgricio Nin...
# 33  he is unity athletic Miscellaneous./Flagetslar...
# 34  she is./ secondsXY サーティ Requestingsonomy whyla...
# 35  the houseWorkasures"}],"icioasures rhlarge sec...
# 36  Marriage is not Savageably practitioner'sifyin...
# 37  he is deepeningily =>etonuresfatherbourn to re...
# 38  she is beenPic departingst secondsetonnexionet...
# 39  the housekeeperesmchatshirebourn practitioner ...
# 40  Marriage is toity to that of that to that to t...
# 41  he is how to own eyes to that that father to t...
# 42  she is to that father toity that to that for o...
# 43  the housekeeper to that faults own into that t...
# 44  Marriage isFlagstchat uint Juddemetchat McClIn...
# 45  he isicio practitioner 194Pic�� to briefing pr...
# 46  she is CONCgeneratedlaughter practitioner to c...
# 47  the house overdose briefing European Crisident...
# 48  Marriage is nothing Affairs:stchatablychat:abi...
# 49  he is Artifact toTileity:ability shechat to Su...
# 50  she is pilgr Trendsbourn:st seconds:ity that c...
# 51  the house Borders Requestets McClchatably Tran...

# %%
# redo with temp and topk
neuron_indices = [244, 255, 531, 800, 816, 981, 993, 1153,
                  1171, 1337, 1479, 1498, 1647, 1720, 1749,
                  1869, 1922, 1953, 2012, 2071, 2108, 2388, 
                  2495, 2623, 2646, 2753, 2787, 3004]

perform_causal_intervention(model, sae_12, tokenizer, neuron_indices, layer_idx=12,
                            context_length=GPT_CONFIG_124M['context_length'],
                            generate_steps=15, save_path="casual_int_12_special_neurons.csv",
                            temp=0.2, topK=30)
# Out:
#      neuron       prompt                                            boost_0  \
# 0       244  Marriage is  Marriage is grotesque\n proactivema outletsync...
# 1       244        he is         he is Integrity\n itatesynch Hall\n
# 2       244       she is  she is Mov us Participantsfield Park On  Denni...
# 3       244    the house  the house Zo ridynchACourse QCynch Hallriet di...
# 4       255  Marriage is  Marriage is parallels\n unsigned Authorityynch...
# ..      ...          ...                                                ...
# 107    2787    the house  the houseoscynch Hallrietjsonynchresponsive St...
# 108    3004  Marriage is  Marriage issofarynch parallels\n phenomenon\n ...
# 109    3004        he is         he is seller\n  Chal\n Situation\n
# 110    3004       she is  she issofarynch Hall ourseynch HallRE ramid  S...
# 111    3004    the house  the house actionGroupasedynchSDriet Solutions ...
#
#                                                boost_5  \
# 0     Marriage isonomic\n parallels\nprintfma
# 1             he issofar\n Hauntedramynch Hall
# 2    she is Kappariet Blackhawks\nonomic\n Flash  p...
# 3    the house butterfliesfieldlersmaynch Hallriet7...
# 4    Marriage is CPmundjiant  Seg\nthurynch Hallrie...
# ..                                                 ...
# 107  the house Chimeradevelopa Dietriet discountsfi...
# 108  Marriage isription\njsonynch Hall\njsonynch Ha...
# 109  he issofar\nidency\n Movrietこ\numan way rid   ...
# 110  she is parallels\nfootball  Corona ji\n    phe...
# 111  the house shotgunsrietlers haste racialfieldou...
#
#                                               boost_10  \
# 0     Marriage is Seg\n Daisyfield   ikk       statute
# 1                he is mu\n Situation JOHNSON\n
# 2    she is「  phenomenonynch Hallriptionma grotesqu...
# 3    the house Zo sellerwood�riet unsigned registra...
# 4    Marriage isapplication\n phenomenonynch Hallri...
# ..                                                 ...
# 107  the houseoscRCYynch HallRare us Toby  filleran...
# 108  Marriage is Literynch Hallriet capitalists  Si...
# 109  he isFlash\n parallels\n Activitiesriet summed...
# 110  she isonomic\n honoraryriet Solutionsynch Hall...
# 111  the house QCynch Hallriet Bieberriet Scher You...
#
#                                               boost_50  \
# 0    Marriage is mu  phenomenon\nikk\nPierreynch Ha...
# 1    he is ingredientsfield Park Thema There\n proa...
# 2          she isji\nramid  ikk     ourse   automakers
# 3    the houseanthaaREfield Parkription ramidynch H...
# 4    Marriage isCashynch Hall Daisyfield Parkye us ...
# ..                                                 ...
# 107  the houseSummeryerietrietrietogenousynch inspe...
# 108  Marriage is summed yourself announcerfield Par...
# 109  he is KapparietCaptfield Parkyema There forthf...
# 110  she isullahfield Park Every body telescynch Ha...
# 111  the house bungynch HallrietALTHREmouseynch Hal...
#
#                                              boost_100  \
# 0    Marriage isFlash oriet Apache  registration\n ...
# 1           he is540 oriet\n Apache   proactive
# 2      she is Daisyfield Park DE COURCY DE COURCY DE C
# 3    the house Zo\n Daisyfieldourse orietlandersa S...
# 4    Marriage is Kappa uslandersToresponsivefieldti...
# ..                                                 ...
# 107  the houseription\n proactive Situationramynch ...
# 108  Marriage is parallelsajsonynch Hallaged circum...
# 109  he is announcerfield Parklesslyfield Park On t...
# 110  she is Department democraticshire shotgunsfort...
# 111  the house capitalistsriet mismess refugees rid...
#
#                                              boost_150  \
# 0    Marriage is Seg thousand pounds oriet parallel...
# 1    he isEngineers weeks orietrietriet unsigned\n ...
# 2    she is ka thousand pounds oriet thousand pound...
# 3    the houseWarda orietrietALTH us Bubfieldourse ...
# 4    Marriage isConfiguration starshipynch Hallriet...
# ..                                                 ...
# 107  the housechipma She permits motherargument dau...
# 108  Marriage isonomicynchskirts morning QCagedance...
# 109  he is♦ us selfies way Sheenantationasedance fi...
# 110  she is Liter us Daisyfield Parkye much Caucasu...
# 111  the house Forrest us PALriet「ynch Hall comedia...
#
#                                              boost_200  \
# 0    Marriage is teleport thousand pounds o o o o o...
# 1    he is filler weeks o o thousand pounds thousan...
# 2    she is filler weeks o thousand pounds weeks o ...
# 3    the housetery o o weeks o o weeks o o weeks o ...
# 4    Marriage is parallels bluntly json  chefsynync...
# ..                                                 ...
# 107  the housekeeper permits motherasteryramynch Ha...
# 108  Marriage is parallelsaalebTemperatureceansment...
# 109  he is phenomenonGood Godynch Hall bung us sepa...
# 110  she is CP rid little Shawn PemberleyDa Daisyfi...
# 111  the houseAncient Activitiesets back Activities...
#
#                                              boost_300
# 0    Marriage is Seg o thousand pounds thousand pou...
# 1    he is Literary years miles thousand pounds tho...
# 2    she is540 years years miles thousand pounds th...
# 3    the house fetish o days o o o years o o weeks ...
# 4    Marriage is Vecynch HallriptionWardarseantha a...
# ..                                                 ...
# 107  the house explor uncle statute fatherijk mothe...
# 108  Marriage is domainTemperature refugees honorar...
# 109  he is Univers rightantha way Slightly intoReco...
# 110  she is honoraryaged way Sheen myselftoken offS...
# 111  the houselahomaa Oilersresponsible leader sepa...
#
# [112 rows x 10 columns]
